# %%
# Load required packages
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import zipfile
import nltk
import os
import string
from nltk import word_tokenize
from nltk.tokenize import sent_tokenize

from transformers import pipeline

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)

# %%
output_dir = 'C:\\Users\\yashd\\Desktop\\URAP\\Code\\Topic_text_csv\\'
content_df = pd.read_csv("merged_content.csv")

# %%
start_index = 504
num_interviews = len(content_df) - start_index
end_index = start_index + num_interviews
content_df = pd.read_csv("merged_content.csv")[start_index: end_index]
content_df = content_df[['text_id', 'compiled_content']].rename(columns = {'compiled_content' : 'content'})
content_df
# Out:
#          text_id                                            content
# 170  33-20-62-30  Hello, how are books? Books are fair. . Okay, ...
# 171  33-21-42-99  So how are you going to face the field since y...
# 172  33-69-32-48  Beatrice how are you? Am okay how are you? You...
# 173  33-83-17-66  Hello am called Brian. Am called Cotilda. How ...
# 174  33-91-51-37  How are you Grace? Am fine how are you? Am fin...
# ..           ...                                                ...
# 499  98-65-25-06  How are you/. Am Shamiya Nassozi. Okay sir. Th...
# 500  99-33-66-89  Hello, Teddy ow are you. Am okay how are you? ...
# 501  99-41-75-39  Hello Madam. Hello, how are you? Am fine Madam...
# 502  99-50-93-22  Hello winnie. Hello Madam. How are you? Am fin...
# 503  99-70-06-07  Hello. Yes please. How are you Dorcas? . Am fi...
#
# [334 rows x 2 columns]

# %%
topics = ['information','strategy', 'motivation', 'neutral']

# %%
# Handles multiple labels associated with each topic
# If avg is true, compute mean similarity across topic terms and return maximum value
# Else, it finds the max value amongst topic terms for each topic, and returns max among those
def topic_classifier(txt, avg = True):
    topic_terms = [['information', 'data'], 
                   ['application', 'cv', 'CV' 'interview', 'strategy', 'job search', 'skills', 'behaviour', 'resume'],
                   ['motivation', 'determination', 'optimism', 'hope']]
    # Obtain dictionaries with the similarity scores with each of the topic related words
    topic_dict = {}
    for i in range(len(topics[:-1])):
        topic_dict[topics[i]] = classifier(txt, topic_terms[i], multi_label = True)['scores']
    
    if avg:
        return max(['information', 'strategy', 'motivation'], key = lambda x: np.mean(topic_dict[x]))
    else:
        return max(['information', 'strategy', 'motivation'], key = lambda x: max(topic_dict[x]))

# %%
def ultimate_tokenize(sentence):
    # Remove punctuation and digits
    sentence = sentence.translate(str.maketrans('', '', string.punctuation + string.digits))
    return word_tokenize(sentence.lower())

# %%
def cleaning(interview):
    
    tokens = ultimate_tokenize(interview)
    from nltk.corpus import stopwords
    
    stops = stopwords.words('english')
    stops.extend(['yeah','hello','ye','yes','okay','ok', 'like', 'uhm','hmmmm','hmmm',
                  'eh', 'yah', 'even', 'good', 'evening', 'lovely', 'thanks', 'really', 'name', 'ayugi'])
    stops.extend('.,[,],(,),;,/,-,\',?,",:,<,>,n\'t,|,#,\'s,\",\'re,\'ve,\'ll,\'d,\'re,’'.split(','))
    stops.extend(',')
    
    # 6. Remove stop words. 
    words = [w for w in tokens if not w in stops]
    
    sent = ' '.join(words)
    return sent

# %%
# Returns dictionary with topics and similarity scores in relation to TXT
def similarity_to_topics(txt):
    topic_dict = classifier(txt, topics, multi_label = True)
    paired_dict = {topic_dict['labels'][i] : topic_dict['scores'][i] for i in range(len(topics))}
    return paired_dict

# %%
# %%time
# Create an array of topic similarity dictionaries and obtain the most similar topic from them and store in two arrays
for i in range(start_index, end_index):
    
    print("Processing Interview", i, "out of", end_index, "with text_id: ",content_df['text_id'][i])
    interview_sent = sent_tokenize(re.sub('(shs)', ' dollars', content_df['content'][i]))
    num_sent = len(interview_sent)
    interview_df = pd.DataFrame({'text_id' : np.repeat(content_df['text_id'][i], num_sent)})
    interview_df['content'] = np.array(interview_sent)
    most_similar_topic_array = np.array([])
    
    for j in range(num_sent):
        if (len(cleaning(interview_df['content'][j])) < 10):
            most_similar_topic_array = np.append(most_similar_topic_array, 'neutral')
        else: 
            similar_topic = topic_classifier(interview_df['content'][j], False)
            most_similar_topic_array = np.append(most_similar_topic_array, similar_topic)

    interview_df['topic'] = most_similar_topic_array    
    save_name = content_df['text_id'][i] + ".csv"
    interview_df.to_csv(output_dir + save_name, index = False)
# Out:
# Processing Interview 170 out of 334 with text_id:  33-20-62-30
# Processing Interview 171 out of 334 with text_id:  33-21-42-99
# Processing Interview 172 out of 334 with text_id:  33-69-32-48
# Processing Interview 173 out of 334 with text_id:  33-83-17-66
# Processing Interview 174 out of 334 with text_id:  33-91-51-37
# Processing Interview 175 out of 334 with text_id:  36-54-28-69
# Processing Interview 176 out of 334 with text_id:  36-81-75-91
# Processing Interview 177 out of 334 with text_id:  37-21-70-94
# Processing Interview 178 out of 334 with text_id:  37-52-72-08
# Processing Interview 179 out of 334 with text_id:  37-91-62-46
# Processing Interview 180 out of 334 with text_id:  38-01-31-63
# Processing Interview 181 out of 334 with text_id:  38-10-90-25
# Processing Interview 182 out of 334 with text_id:  38-12-17-88
# Processing Interview 183 out of 334 with text_id:  38-40-59-75
# Processing Interview 184 out of 334 with text_id:  39-25-69-54
# Processing Interview 185 out of 334 with text_id:  40-10-04-29
# Processing Interview 186 out of 334 with text_id:  40-18-76-08
# Processing Interview 187 out of 334 with text_id:  40-28-91-72
# Processing Interview 188 out of 334 with text_id:  40-29-15-94
# Processing Interview 189 out of 334 with text_id:  40-36-30-67
# Processing Interview 190 out of 334 with text_id:  40-42-21-72
# Processing Interview 191 out of 334 with text_id:  40-46-55-15
# Processing Interview 192 out of 334 with text_id:  40-62-03-42
# Processing Interview 193 out of 334 with text_id:  40-95-43-37
# Processing Interview 194 out of 334 with text_id:  41-16-47-14
# Processing Interview 195 out of 334 with text_id:  41-23-62-60
# Processing Interview 196 out of 334 with text_id:  41-28-94-95
# Processing Interview 197 out of 334 with text_id:  41-53-43-93
# Processing Interview 198 out of 334 with text_id:  41-93-41-50
# Processing Interview 199 out of 334 with text_id:  42-12-78-21
# Processing Interview 200 out of 334 with text_id:  42-91-12-32
# Processing Interview 201 out of 334 with text_id:  43-56-55-82
# Processing Interview 202 out of 334 with text_id:  43-60-32-60
# Processing Interview 203 out of 334 with text_id:  43-79-60-39
# Processing Interview 204 out of 334 with text_id:  43-82-81-11
# Processing Interview 205 out of 334 with text_id:  43-89-00-48
# Processing Interview 206 out of 334 with text_id:  44-04-26-16
# Processing Interview 207 out of 334 with text_id:  44-50-30-23
# Processing Interview 208 out of 334 with text_id:  44-59-23-87
# Processing Interview 209 out of 334 with text_id:  44-77-56-84
# Processing Interview 210 out of 334 with text_id:  44-82-56-20
# Processing Interview 211 out of 334 with text_id:  44-93-32-69
# Processing Interview 212 out of 334 with text_id:  45-06-64-71
# Processing Interview 213 out of 334 with text_id:  45-08-57-72
# Processing Interview 214 out of 334 with text_id:  45-24-14-48
# Processing Interview 215 out of 334 with text_id:  45-31-34-47
# Processing Interview 216 out of 334 with text_id:  45-40-21-65
# Processing Interview 217 out of 334 with text_id:  45-76-42-24
# Processing Interview 218 out of 334 with text_id:  46-25-68-50
# Processing Interview 219 out of 334 with text_id:  46-45-32-00
# Processing Interview 220 out of 334 with text_id:  46-61-49-97
# Processing Interview 221 out of 334 with text_id:  46-64-15-68
# Processing Interview 222 out of 334 with text_id:  46-78-20-49
# Processing Interview 223 out of 334 with text_id:  46-82-91-67
# Processing Interview 224 out of 334 with text_id:  47-12-15-97
# Processing Interview 225 out of 334 with text_id:  47-17-78-78
# Processing Interview 226 out of 334 with text_id:  47-24-90-18
# Processing Interview 227 out of 334 with text_id:  47-30-60-20
# Processing Interview 228 out of 334 with text_id:  47-35-89-85
# Processing Interview 229 out of 334 with text_id:  47-70-02-76
# Processing Interview 230 out of 334 with text_id:  48-00-03-18
# Processing Interview 231 out of 334 with text_id:  48-03-48-53
# Processing Interview 232 out of 334 with text_id:  48-18-37-30
# Processing Interview 233 out of 334 with text_id:  48-25-63-06
# Processing Interview 234 out of 334 with text_id:  48-61-72-48
# Processing Interview 235 out of 334 with text_id:  48-63-86-81
# Processing Interview 236 out of 334 with text_id:  48-74-61-04
# Processing Interview 237 out of 334 with text_id:  48-81-65-78
# Processing Interview 238 out of 334 with text_id:  48-83-54-63
# Processing Interview 239 out of 334 with text_id:  48-83-71-57
# Processing Interview 240 out of 334 with text_id:  48-94-57-41
# Processing Interview 241 out of 334 with text_id:  48-99-57-33
# Processing Interview 242 out of 334 with text_id:  49-22-77-76
# Processing Interview 243 out of 334 with text_id:  49-37-11-08
# Processing Interview 244 out of 334 with text_id:  49-55-01-45
# Processing Interview 245 out of 334 with text_id:  49-61-23-72
# Processing Interview 246 out of 334 with text_id:  49-65-06-39
# Processing Interview 247 out of 334 with text_id:  49-74-14-43
# Processing Interview 248 out of 334 with text_id:  49-74-28-24
# Processing Interview 249 out of 334 with text_id:  49-95-83-43
# Processing Interview 250 out of 334 with text_id:  50-37-65-01
# Processing Interview 251 out of 334 with text_id:  50-48-59-04
# Processing Interview 252 out of 334 with text_id:  50-81-56-52
# Processing Interview 253 out of 334 with text_id:  50-87-65-26
# Processing Interview 254 out of 334 with text_id:  50-90-37-72
# Processing Interview 255 out of 334 with text_id:  50-93-79-87
# Processing Interview 256 out of 334 with text_id:  51-53-73-38
# Processing Interview 257 out of 334 with text_id:  51-67-93-45
# Processing Interview 258 out of 334 with text_id:  52-06-95-48
# Processing Interview 259 out of 334 with text_id:  52-26-82-71
# Processing Interview 260 out of 334 with text_id:  52-64-77-36
# Processing Interview 261 out of 334 with text_id:  52-66-02-44
# Processing Interview 262 out of 334 with text_id:  52-74-41-97
# Processing Interview 263 out of 334 with text_id:  52-75-71-85
# Processing Interview 264 out of 334 with text_id:  53-00-40-13
# Processing Interview 265 out of 334 with text_id:  53-43-97-70
# Processing Interview 266 out of 334 with text_id:  53-82-53-89
# Processing Interview 267 out of 334 with text_id:  54-13-57-92
# Processing Interview 268 out of 334 with text_id:  54-26-05-70
# Processing Interview 269 out of 334 with text_id:  54-39-83-82
# Processing Interview 270 out of 334 with text_id:  54-41-91-52
# Processing Interview 271 out of 334 with text_id:  54-50-66-40
# Processing Interview 272 out of 334 with text_id:  54-54-19-86
# Processing Interview 273 out of 334 with text_id:  54-87-28-26
# Processing Interview 274 out of 334 with text_id:  55-07-36-79
# Processing Interview 275 out of 334 with text_id:  55-21-63-00
# Processing Interview 276 out of 334 with text_id:  55-86-31-26
# Processing Interview 277 out of 334 with text_id:  56-06-09-56
# Processing Interview 278 out of 334 with text_id:  56-10-77-25
# Processing Interview 279 out of 334 with text_id:  56-19-65-80
# Processing Interview 280 out of 334 with text_id:  56-43-02-32
# Processing Interview 281 out of 334 with text_id:  56-57-61-58
# Processing Interview 282 out of 334 with text_id:  57-01-72-08
# Processing Interview 283 out of 334 with text_id:  57-06-45-54
# Processing Interview 284 out of 334 with text_id:  57-14-75-78
# Processing Interview 285 out of 334 with text_id:  57-71-52-70
# Processing Interview 286 out of 334 with text_id:  57-98-94-14
# Processing Interview 287 out of 334 with text_id:  58-18-05-90
# Processing Interview 288 out of 334 with text_id:  58-43-50-59
# Processing Interview 289 out of 334 with text_id:  58-65-53-96
# Processing Interview 290 out of 334 with text_id:  58-66-86-06
# Processing Interview 291 out of 334 with text_id:  58-71-53-02
# Processing Interview 292 out of 334 with text_id:  59-33-77-26
# Processing Interview 293 out of 334 with text_id:  59-48-29-06
# Processing Interview 294 out of 334 with text_id:  59-60-06-65
# Processing Interview 295 out of 334 with text_id:  59-86-64-56
# Processing Interview 296 out of 334 with text_id:  60-03-79-71
# Processing Interview 297 out of 334 with text_id:  60-08-78-34
# Processing Interview 298 out of 334 with text_id:  60-33-60-06
# Processing Interview 299 out of 334 with text_id:  60-49-43-72
# Processing Interview 300 out of 334 with text_id:  60-81-56-66
# Processing Interview 301 out of 334 with text_id:  61-09-52-60
# Processing Interview 302 out of 334 with text_id:  61-28-35-56
# Processing Interview 303 out of 334 with text_id:  61-35-75-36
# Processing Interview 304 out of 334 with text_id:  61-55-75-84
# Processing Interview 305 out of 334 with text_id:  61-59-98-62
# Processing Interview 306 out of 334 with text_id:  61-98-97-76
# Processing Interview 307 out of 334 with text_id:  62-15-83-01
# Processing Interview 308 out of 334 with text_id:  62-16-88-48
# Processing Interview 309 out of 334 with text_id:  62-20-22-64
# Processing Interview 310 out of 334 with text_id:  62-33-10-15
# Processing Interview 311 out of 334 with text_id:  62-43-74-50
# Processing Interview 312 out of 334 with text_id:  62-78-18-79
# Processing Interview 313 out of 334 with text_id:  62-84-78-25
# Processing Interview 314 out of 334 with text_id:  62-90-15-21
# Processing Interview 315 out of 334 with text_id:  63-19-99-89
# Processing Interview 316 out of 334 with text_id:  63-23-59-96
# Processing Interview 317 out of 334 with text_id:  63-29-45-68
# Processing Interview 318 out of 334 with text_id:  63-33-07-89
# Processing Interview 319 out of 334 with text_id:  63-34-35-07
# Processing Interview 320 out of 334 with text_id:  63-65-48-00
# Processing Interview 321 out of 334 with text_id:  63-79-33-49
# Processing Interview 322 out of 334 with text_id:  63-86-60-48
# Processing Interview 323 out of 334 with text_id:  64-00-91-24
# Processing Interview 324 out of 334 with text_id:  64-16-62-76
# Processing Interview 325 out of 334 with text_id:  64-23-96-45
# Processing Interview 326 out of 334 with text_id:  64-31-66-47
# Processing Interview 327 out of 334 with text_id:  64-52-89-43
# Processing Interview 328 out of 334 with text_id:  64-75-18-43
# Processing Interview 329 out of 334 with text_id:  64-94-40-40
# Processing Interview 330 out of 334 with text_id:  65-02-68-53
# Processing Interview 331 out of 334 with text_id:  65-08-97-98
# Processing Interview 332 out of 334 with text_id:  65-11-35-33
# Processing Interview 333 out of 334 with text_id:  65-17-40-46
# Processing Interview 334 out of 334 with text_id:  65-25-16-48
# Processing Interview 335 out of 334 with text_id:  65-26-03-17
# Processing Interview 336 out of 334 with text_id:  65-29-33-65
# Processing Interview 337 out of 334 with text_id:  65-42-41-98
# Processing Interview 338 out of 334 with text_id:  65-50-30-28
# Processing Interview 339 out of 334 with text_id:  66-30-67-99
# Processing Interview 340 out of 334 with text_id:  66-42-42-23
# Processing Interview 341 out of 334 with text_id:  66-78-36-28
# Processing Interview 342 out of 334 with text_id:  66-85-84-61
# Processing Interview 343 out of 334 with text_id:  67-01-50-28
# Processing Interview 344 out of 334 with text_id:  67-08-50-15
# Processing Interview 345 out of 334 with text_id:  67-15-20-14
# Processing Interview 346 out of 334 with text_id:  67-22-69-21
# Processing Interview 347 out of 334 with text_id:  67-33-98-13
# Processing Interview 348 out of 334 with text_id:  67-50-04-03
# Processing Interview 349 out of 334 with text_id:  68-00-94-60
# Processing Interview 350 out of 334 with text_id:  68-07-34-03
# Processing Interview 351 out of 334 with text_id:  68-49-64-01
# Processing Interview 352 out of 334 with text_id:  68-53-10-83
# Processing Interview 353 out of 334 with text_id:  68-58-30-85
# Processing Interview 354 out of 334 with text_id:  69-07-50-54
# Processing Interview 355 out of 334 with text_id:  69-31-60-46
# Processing Interview 356 out of 334 with text_id:  69-49-79-19
# Processing Interview 357 out of 334 with text_id:  69-53-37-16
# Processing Interview 358 out of 334 with text_id:  69-76-97-63
# Processing Interview 359 out of 334 with text_id:  69-80-36-18
# Processing Interview 360 out of 334 with text_id:  70-05-83-64
# Processing Interview 361 out of 334 with text_id:  70-10-17-55
# Processing Interview 362 out of 334 with text_id:  70-33-67-03
# Processing Interview 363 out of 334 with text_id:  70-38-17-48
# Processing Interview 364 out of 334 with text_id:  70-49-24-51
# Processing Interview 365 out of 334 with text_id:  70-54-19-31
# Processing Interview 366 out of 334 with text_id:  70-75-07-94
# Processing Interview 367 out of 334 with text_id:  71-05-46-50
# Processing Interview 368 out of 334 with text_id:  71-06-84-16
# Processing Interview 369 out of 334 with text_id:  71-08-75-36
# Processing Interview 370 out of 334 with text_id:  71-12-70-56
# Processing Interview 371 out of 334 with text_id:  71-56-31-73
# Processing Interview 372 out of 334 with text_id:  71-57-34-51
# Processing Interview 373 out of 334 with text_id:  71-71-98-82
# Processing Interview 374 out of 334 with text_id:  71-77-59-06
# Processing Interview 375 out of 334 with text_id:  71-94-67-42
# Processing Interview 376 out of 334 with text_id:  71-97-13-57
# Processing Interview 377 out of 334 with text_id:  72-03-40-61
# Processing Interview 378 out of 334 with text_id:  72-50-82-82
# Processing Interview 379 out of 334 with text_id:  72-66-55-99
# Processing Interview 380 out of 334 with text_id:  72-71-09-17
# Processing Interview 381 out of 334 with text_id:  73-63-68-97
# Processing Interview 382 out of 334 with text_id:  73-75-04-64
# Processing Interview 383 out of 334 with text_id:  74-29-23-81
# Processing Interview 384 out of 334 with text_id:  74-31-24-52
# Processing Interview 385 out of 334 with text_id:  74-50-76-81
# Processing Interview 386 out of 334 with text_id:  74-67-84-02
# Processing Interview 387 out of 334 with text_id:  74-96-37-97
# Processing Interview 388 out of 334 with text_id:  75-02-29-69
# Processing Interview 389 out of 334 with text_id:  75-21-78-68
# Processing Interview 390 out of 334 with text_id:  75-35-15-07
# Processing Interview 391 out of 334 with text_id:  75-35-19-33
# Processing Interview 392 out of 334 with text_id:  75-64-30-45
# Processing Interview 393 out of 334 with text_id:  75-80-45-33
# Processing Interview 394 out of 334 with text_id:  75-87-29-25
# Processing Interview 395 out of 334 with text_id:  75-98-78-24
# Processing Interview 396 out of 334 with text_id:  76-51-48-17
# Processing Interview 397 out of 334 with text_id:  76-85-04-78
# Processing Interview 398 out of 334 with text_id:  76-86-27-40
# Processing Interview 399 out of 334 with text_id:  77-21-81-30
# Processing Interview 400 out of 334 with text_id:  77-41-75-60
# Processing Interview 401 out of 334 with text_id:  77-54-88-08
# Processing Interview 402 out of 334 with text_id:  77-61-53-33
# Processing Interview 403 out of 334 with text_id:  77-62-86-67
# Processing Interview 404 out of 334 with text_id:  77-77-82-75
# Processing Interview 405 out of 334 with text_id:  78-01-87-99
# Processing Interview 406 out of 334 with text_id:  78-06-02-00
# Processing Interview 407 out of 334 with text_id:  78-16-76-18
# Processing Interview 408 out of 334 with text_id:  78-74-69-02
# Processing Interview 409 out of 334 with text_id:  79-24-39-93
# Processing Interview 410 out of 334 with text_id:  79-27-34-33
# Processing Interview 411 out of 334 with text_id:  79-64-53-59
# Processing Interview 412 out of 334 with text_id:  79-68-82-69
# Processing Interview 413 out of 334 with text_id:  79-72-07-89
# Processing Interview 414 out of 334 with text_id:  79-73-13-61
# Processing Interview 415 out of 334 with text_id:  80-22-16-23
# Processing Interview 416 out of 334 with text_id:  80-39-16-19
# Processing Interview 417 out of 334 with text_id:  80-63-71-58
# Processing Interview 418 out of 334 with text_id:  80-64-12-47
# Processing Interview 419 out of 334 with text_id:  80-64-30-46
# Processing Interview 420 out of 334 with text_id:  80-95-04-79
# Processing Interview 421 out of 334 with text_id:  81-03-74-25
# Processing Interview 422 out of 334 with text_id:  81-03-90-35
# Processing Interview 423 out of 334 with text_id:  81-03-98-65
# Processing Interview 424 out of 334 with text_id:  81-07-36-79
# Processing Interview 425 out of 334 with text_id:  81-21-15-84
# Processing Interview 426 out of 334 with text_id:  81-30-02-12
# Processing Interview 427 out of 334 with text_id:  81-45-63-10
# Processing Interview 428 out of 334 with text_id:  81-78-03-97
# Processing Interview 429 out of 334 with text_id:  82-72-04-99
# Processing Interview 430 out of 334 with text_id:  82-95-54-79
# Processing Interview 431 out of 334 with text_id:  82-98-57-75
# Processing Interview 432 out of 334 with text_id:  83-28-82-19
# Processing Interview 433 out of 334 with text_id:  83-33-92-10
# Processing Interview 434 out of 334 with text_id:  83-81-94-08
# Processing Interview 435 out of 334 with text_id:  83-93-53-14
# Processing Interview 436 out of 334 with text_id:  83-99-49-64
# Processing Interview 437 out of 334 with text_id:  84-01-59-14
# Processing Interview 438 out of 334 with text_id:  84-17-89-53
# Processing Interview 439 out of 334 with text_id:  84-91-04-70
# Processing Interview 440 out of 334 with text_id:  85-03-35-65
# Processing Interview 441 out of 334 with text_id:  85-13-45-53
# Processing Interview 442 out of 334 with text_id:  85-62-79-14
# Processing Interview 443 out of 334 with text_id:  85-96-36-37
# Processing Interview 444 out of 334 with text_id:  86-07-82-51
# Processing Interview 445 out of 334 with text_id:  86-53-61-40
# Processing Interview 446 out of 334 with text_id:  86-68-29-97
# Processing Interview 447 out of 334 with text_id:  86-89-49-64
# Processing Interview 448 out of 334 with text_id:  87-15-45-59
# Processing Interview 449 out of 334 with text_id:  87-31-11-70
# Processing Interview 450 out of 334 with text_id:  87-38-15-66
# Processing Interview 451 out of 334 with text_id:  87-72-14-26
# Processing Interview 452 out of 334 with text_id:  88-29-41-17
# Processing Interview 453 out of 334 with text_id:  88-43-94-84
# Processing Interview 454 out of 334 with text_id:  88-47-32-12
# Processing Interview 455 out of 334 with text_id:  88-63-71-56
# Processing Interview 456 out of 334 with text_id:  88-77-65-75
# Processing Interview 457 out of 334 with text_id:  89-11-61-59
# Processing Interview 458 out of 334 with text_id:  89-39-31-62
# Processing Interview 459 out of 334 with text_id:  89-74-45-58
# Processing Interview 460 out of 334 with text_id:  89-75-97-26
# Processing Interview 461 out of 334 with text_id:  89-79-86-15
# Processing Interview 462 out of 334 with text_id:  89-86-54-69
# Processing Interview 463 out of 334 with text_id:  90-13-22-63
# Processing Interview 464 out of 334 with text_id:  90-13-48-22
# Processing Interview 465 out of 334 with text_id:  90-37-69-44
# Processing Interview 466 out of 334 with text_id:  90-40-84-16
# Processing Interview 467 out of 334 with text_id:  90-49-77-40
# Processing Interview 468 out of 334 with text_id:  90-91-96-93
# Processing Interview 469 out of 334 with text_id:  91-26-45-02
# Processing Interview 470 out of 334 with text_id:  91-40-00-29
# Processing Interview 471 out of 334 with text_id:  91-80-21-05
# Processing Interview 472 out of 334 with text_id:  91-90-52-68
# Processing Interview 473 out of 334 with text_id:  91-91-83-54
# Processing Interview 474 out of 334 with text_id:  91-92-12-96
# Processing Interview 475 out of 334 with text_id:  92-11-56-93
# Processing Interview 476 out of 334 with text_id:  92-30-48-34
# Processing Interview 477 out of 334 with text_id:  92-50-28-06
# Processing Interview 478 out of 334 with text_id:  92-72-15-06
# Processing Interview 479 out of 334 with text_id:  93-09-89-20
# Processing Interview 480 out of 334 with text_id:  93-42-62-57
# Processing Interview 481 out of 334 with text_id:  93-81-69-80
# Processing Interview 482 out of 334 with text_id:  93-82-19-69
# Processing Interview 483 out of 334 with text_id:  94-04-43-13
# Processing Interview 484 out of 334 with text_id:  94-10-82-27
# Processing Interview 485 out of 334 with text_id:  94-11-69-04
# Processing Interview 486 out of 334 with text_id:  94-40-63-41
# Processing Interview 487 out of 334 with text_id:  94-45-87-93
# Processing Interview 488 out of 334 with text_id:  94-59-91-81
# Processing Interview 489 out of 334 with text_id:  95-11-24-52
# Processing Interview 490 out of 334 with text_id:  95-34-72-01
# Processing Interview 491 out of 334 with text_id:  95-35-43-32
# Processing Interview 492 out of 334 with text_id:  96-84-50-16
# Processing Interview 493 out of 334 with text_id:  97-35-78-19
# Processing Interview 494 out of 334 with text_id:  97-42-10-30
# Processing Interview 495 out of 334 with text_id:  97-50-76-92
# Processing Interview 496 out of 334 with text_id:  98-06-43-37
# Processing Interview 497 out of 334 with text_id:  98-30-90-24
# Processing Interview 498 out of 334 with text_id:  98-50-98-78
# Processing Interview 499 out of 334 with text_id:  98-65-25-06
# Processing Interview 500 out of 334 with text_id:  99-33-66-89
# Processing Interview 501 out of 334 with text_id:  99-41-75-39
# Processing Interview 502 out of 334 with text_id:  99-50-93-22
# Processing Interview 503 out of 334 with text_id:  99-70-06-07
# Wall time: 19h 10min 1s
