# %%
# Load required packages
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from transformers import pipeline

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)

# %%
cd
# Out:
# C:\Users\yashd

# %%
# Loading up test cases
strategy_info_test = pd.read_csv("Desktop/URAP/Strategy_Info_Test.csv")
strategy_info_test
# Out:
#                                               content        Topic
# 0                        the unemployment rate is 38%  Information
# 1        here is advice on how to get a higher salary     Strategy
# 2   most companies don’t want to use students they...     Strategy
# 3   if you get an internship offer but the pay at ...  Information
# 4   builders tend to use vulgar language so try as...  Information
# 5         employers are not hiring workers at present  Information
# 6    You have to find deduct your capital and see ...  Information
# 7   You get connections through you friends becaus...     Strategy
# 8   Like how to write a CV because when you apply ...     Strategy
# 9   That’s being impatient and how do you talk to ...     Strategy
# 10  Okay allow me take you through that, now you w...     Strategy
# 11  Okay that’s good, you come out of school and y...     Strategy
# 12  Don’t apply at only one place, Drop your CVs a...     Strategy
# 13  For us ladies when you are looking for a job y...  Information
# 14  Most of our salaries start from 200,000. 300.0...  Information
# 15  You see plumbing is a very good course and its...  Information
# 16  Working experience plus connections is what ma...     Strategy
# 17  DIT is very good and its mostly considered in ...  Information
# 18  Even if challenges come, you have to stay focu...   Motivation
# 19   Some companies may decide to employ you with ...     Strategy
# 20  We most cases we tend to lose hope after tryin...   Motivation
# 21                         You have to be determined.   Motivation
# 22  You also have to be honesty, faithful and have...   Motivation
# 23  The ability to recover after failure should al...   Motivation
# 24  When you are confident I believe you can do an...   Motivation
# 25  The truth is everyone would want to start thei...     Strategy
# 26  That is how you can adapt the industry where w...  Information
# 27  You have to first teach pupils and he sees the...  Information
# 28  Even when you are looking for a job by the way...     Strategy
# 29  Actually for you who has just come out even if...  Information
# 30  How to prepare your documents, what is need, h...     Strategy
# 31  So you need to know more on how to go about th...     Strategy
# 32  So my advice is that get a stationary near whe...     Strategy
# 33  Let me take it that you were taught how to wri...     Strategy

# %%
topics = ['information','strategy', 'motivation', 'neutral']

# %%
# Returns dictionary with topics and similarity scores in relation to TXT
def similarity_to_topics(txt):
    topic_dict = classifier(txt, topics, multi_label = True)
    paired_dict = {topic_dict['labels'][i] : topic_dict['scores'][i] for i in range(len(topics))}
    return paired_dict

# %%
def similarity_to_topic_terms(txt):
    topic_scores = []
    topic_dict = {}
    i = 0
    for topic_words in topic_terms:
        topic_classifier = classifier(txt, topic_words, multi_label = True)
        topic_dict[topics[i]] = np.mean(topic_classifier['scores'])
        i = i + 1
    return topic_dict

# %%
# Handles multiple labels associated with each topic
# If avg is true, compute mean similarity across topic labels and return maximum value
# Else, it finds the max value amongst topic labels for each topic, and returns max among those
def strategy_info_classify(txt, avg = True):
    topic_terms = [['information', 'data'], 
                   ['application', 'cv', 'CV' 'interview', 'strategy', 'job search', 'skills', 'behaviour', 'resume'],
                   ['motivation', 'determination', 'optimism', 'hope']]
    # Obtain dictionaries with the similarity scores with each of the topic related words
    topic_dict = {}
    for i in range(len(topics[:-1])):
        topic_dict[topics[i]] = classifier(txt, topic_terms[i], multi_label = True)['scores']
    
    
    if avg:
        return max(['information', 'strategy', 'motivation'], key = lambda x: np.mean(topic_dict[x]))
    else:
        return max(['information', 'strategy', 'motivation'], key = lambda x: max(topic_dict[x]))

# %%
# %%time
# Create an array of topic similarity dictionaries and obtain the most similar topic from them and store in two arrays
topic_dict_array = np.array([])
most_similar_topic_array = np.array([])
for i in range(len(strategy_info_test)):
    topic_dict = similarity_to_topics(strategy_info_test['content'][i])
    topic_dict_array = np.append(topic_dict_array, topic_dict)
    similar_topic = sorted(topic_dict.items(), key=lambda x: x[1], reverse=True)[0][0]
    
    # To differentiate between strategy and information better, additional function with topic-related words
    if (similar_topic == 'strategy' or similar_topic == 'information'): # and abs(topic_dict['strategy'] - topic_dict['information']) > 0.20
        similar_topic = strategy_info_classify(strategy_info_test['content'][i], False)
    most_similar_topic_array = np.append(most_similar_topic_array, similar_topic)

# Add those two arrays as columns
strategy_info_test['predicted_topic'] = most_similar_topic_array    
strategy_info_test['topic_dict'] = topic_dict_array
  
# Extract the topic-specific scores and store them into their respective column in the dataframe
for i in range(len(topics)):
    strategy_info_test[topics[i]] = strategy_info_test['topic_dict'].apply(lambda x: x[topics[i]])
strategy_info_test
# Out:
# Wall time: 2min 1s
#                                               content        Topic  \
# 0                        the unemployment rate is 38%  Information
# 1        here is advice on how to get a higher salary     Strategy
# 2   most companies don’t want to use students they...     Strategy
# 3   if you get an internship offer but the pay at ...  Information
# 4   builders tend to use vulgar language so try as...  Information
# 5         employers are not hiring workers at present  Information
# 6    You have to find deduct your capital and see ...  Information
# 7   You get connections through you friends becaus...     Strategy
# 8   Like how to write a CV because when you apply ...     Strategy
# 9   That’s being impatient and how do you talk to ...     Strategy
# 10  Okay allow me take you through that, now you w...     Strategy
# 11  Okay that’s good, you come out of school and y...     Strategy
# 12  Don’t apply at only one place, Drop your CVs a...     Strategy
# 13  For us ladies when you are looking for a job y...  Information
# 14  Most of our salaries start from 200,000. 300.0...  Information
# 15  You see plumbing is a very good course and its...  Information
# 16  Working experience plus connections is what ma...     Strategy
# 17  DIT is very good and its mostly considered in ...  Information
# 18  Even if challenges come, you have to stay focu...   Motivation
# 19   Some companies may decide to employ you with ...     Strategy
# 20  We most cases we tend to lose hope after tryin...   Motivation
# 21                         You have to be determined.   Motivation
# 22  You also have to be honesty, faithful and have...   Motivation
# 23  The ability to recover after failure should al...   Motivation
# 24  When you are confident I believe you can do an...   Motivation
# 25  The truth is everyone would want to start thei...     Strategy
# 26  That is how you can adapt the industry where w...  Information
# 27  You have to first teach pupils and he sees the...  Information
# 28  Even when you are looking for a job by the way...     Strategy
# 29  Actually for you who has just come out even if...  Information
# 30  How to prepare your documents, what is need, h...     Strategy
# 31  So you need to know more on how to go about th...     Strategy
# 32  So my advice is that get a stationary near whe...     Strategy
# 33  Let me take it that you were taught how to wri...     Strategy
#
#    predicted_topic                                         topic_dict  \
# 0      information  {'information': 0.8781885504722595, 'strategy'...
# 1      information  {'information': 0.9900729060173035, 'strategy'...
# 2         strategy  {'strategy': 0.8940097093582153, 'information'...
# 3      information  {'information': 0.8243071436882019, 'strategy'...
# 4         strategy  {'strategy': 0.4126897156238556, 'information'...
# 5         strategy  {'information': 0.6336061358451843, 'strategy'...
# 6      information  {'information': 0.9414877891540527, 'strategy'...
# 7         strategy  {'strategy': 0.9697263240814209, 'information'...
# 8         strategy  {'information': 0.9749327898025513, 'strategy'...
# 9         strategy  {'strategy': 0.04517253860831261, 'information...
# 10        strategy  {'information': 0.987444281578064, 'strategy':...
# 11        strategy  {'information': 0.9714141488075256, 'motivatio...
# 12        strategy  {'strategy': 0.9933854937553406, 'information'...
# 13        strategy  {'information': 0.9900214672088623, 'strategy'...
# 14     information  {'information': 0.746570885181427, 'motivation...
# 15     information  {'information': 0.9714549779891968, 'motivatio...
# 16     information  {'information': 0.8354567289352417, 'strategy'...
# 17        strategy  {'information': 0.6104717254638672, 'motivatio...
# 18      motivation  {'strategy': 0.7684531211853027, 'motivation':...
# 19     information  {'information': 0.7633585929870605, 'strategy'...
# 20        strategy  {'information': 0.8114591240882874, 'motivatio...
# 21      motivation  {'motivation': 0.9338276386260986, 'informatio...
# 22      motivation  {'information': 0.7609902024269104, 'motivatio...
# 23        strategy  {'information': 0.4905746877193451, 'strategy'...
# 24      motivation  {'motivation': 0.8010408282279968, 'informatio...
# 25        strategy  {'information': 0.8808250427246094, 'strategy'...
# 26        strategy  {'strategy': 0.8856452703475952, 'information'...
# 27     information  {'information': 0.9349536299705505, 'strategy'...
# 28        strategy  {'information': 0.8314244747161865, 'motivatio...
# 29      motivation  {'information': 0.8810798525810242, 'motivatio...
# 30     information  {'information': 0.9752146005630493, 'strategy'...
# 31        strategy  {'information': 0.9920399188995361, 'strategy'...
# 32        strategy  {'information': 0.814713716506958, 'motivation...
# 33        strategy  {'information': 0.9593701958656311, 'motivatio...
#
#     information  strategy  motivation   neutral
# 0      0.878189  0.036110    0.017900  0.001567
# 1      0.990073  0.957627    0.337709  0.000831
# 2      0.788155  0.894010    0.366814  0.024042
# 3      0.824307  0.164881    0.091134  0.005612
# 4      0.145049  0.412690    0.114811  0.001173
# 5      0.633606  0.617034    0.225548  0.072824
# 6      0.941488  0.286889    0.106728  0.005053
# 7      0.916910  0.969726    0.839900  0.013520
# 8      0.974933  0.033387    0.018218  0.008063
# 9      0.004795  0.045173    0.002029  0.000371
# 10     0.987444  0.509618    0.385525  0.012594
# 11     0.971414  0.373208    0.851085  0.018971
# 12     0.972674  0.993385    0.948261  0.019827
# 13     0.990021  0.807910    0.629531  0.004146
# 14     0.746571  0.411473    0.434708  0.014731
# 15     0.971455  0.112250    0.571183  0.014346
# 16     0.835457  0.275776    0.057372  0.004949
# 17     0.610472  0.036445    0.087887  0.006861
# 18     0.419675  0.768453    0.580883  0.012629
# 19     0.763359  0.753624    0.291929  0.006403
# 20     0.811459  0.539532    0.806764  0.008826
# 21     0.655695  0.518625    0.933828  0.015592
# 22     0.760990  0.410862    0.598697  0.005852
# 23     0.490575  0.234336    0.145257  0.013923
# 24     0.662971  0.322114    0.801041  0.031159
# 25     0.880825  0.740199    0.575853  0.031488
# 26     0.881521  0.885645    0.061921  0.008026
# 27     0.934954  0.734086    0.355383  0.015945
# 28     0.831424  0.067510    0.115512  0.008793
# 29     0.881080  0.768055    0.825769  0.006894
# 30     0.975215  0.893222    0.349700  0.006148
# 31     0.992040  0.843899    0.017539  0.007115
# 32     0.814714  0.568334    0.750542  0.007024
# 33     0.959370  0.120100    0.248167  0.137028

# %%
# Compute the accuracy of the classification process
accurate = np.count_nonzero(strategy_info_test['Topic'].apply(lambda x: x.lower()) == strategy_info_test['predicted_topic'])
print("Accuracy:", accurate, "out of", len(strategy_info_test), "=", np.round(accurate/len(strategy_info_test), 4) * 100, "%" )
# Out:
# Accuracy: 22 out of 34 = 64.71000000000001 %

# %%
# Obtain actual and expected counts for labelled sentences
actual_count_dict = {topic : 0 for topic in topics}
expected_count_dict = {topic : 0 for topic in topics}
for i in range(len(strategy_info_test)):
    actual_count_dict[strategy_info_test['predicted_topic'][i]] += 1
    expected_count_dict[strategy_info_test['Topic'][i].lower()] += 1

# %%
summary_df = pd.DataFrame([expected_count_dict, actual_count_dict])
summary_df.index = ['Expected Count', 'Actual Count']
summary_df
# Out:
#                 information  strategy  motivation  neutral
# Expected Count           12        16           6        0
# Actual Count             10        19           5        0
